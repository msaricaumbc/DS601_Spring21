# %%
import os
import json
import re

# %%
def find_all_notebooks(folder='../../'):
    """
    Gets file paths and file names for all .ipynb files in a given folder 
    
    Parameters:
    –––––––––––
    folder: str
    
    Returns:
    ––––––––
    paths: list
        list of tuples with file path and file name
    """
    paths = []
    for root, dirs, files in os.walk(folder):
        for file in files:
            if any([file.endswith(ft) for ft in ['.ipynb']]):
                if 'Week11 Solution' not in file: # optional
                    path = (os.path.join(root, file), file)
                    paths.append(path)
    
    return paths

# %%
all_notebooks = find_all_notebooks()
all_notebooks[:10]
# Out:
# [('../../Week6/HomeworkWeek6.ipynb', 'HomeworkWeek6.ipynb'),
#  ('../../Week6/HomeworkWeek6_Solution.ipynb', 'HomeworkWeek6_Solution.ipynb'),
#  ('../../Week6/.ipynb_checkpoints/HomeworkWeek6_Solution-checkpoint.ipynb',
#   'HomeworkWeek6_Solution-checkpoint.ipynb'),
#  ('../../Week6/.ipynb_checkpoints/HomeworkWeek6-checkpoint.ipynb',
#   'HomeworkWeek6-checkpoint.ipynb'),
#  ('../../Week1/Untitled.ipynb', 'Untitled.ipynb'),
#  ('../../Week1/load_csv.ipynb', 'load_csv.ipynb'),
#  ('../../Week1/Week1 - Some basics.ipynb', 'Week1 - Some basics.ipynb'),
#  ('../../Week1/Homework-week1.ipynb', 'Homework-week1.ipynb'),
#  ('../../Week1/Challenge.ipynb', 'Challenge.ipynb'),
#  ('../../Week1/load_xml.ipynb', 'load_xml.ipynb')]

# %%
def get_content(path):
    with open(path) as f:
        lines = f.readlines()
        return '\n'.join(lines)

# %%
def get_modules_from_notebook(path):
    modules = []
    
    text = get_content(path)
    
    # from nltk.corpus import stopwords 
    # import pandas
    # pattern explanation
    # from      literal text
    # \s+       space one or more
    # [\w\.]+  some any word character _ and . one or more times abb.abb or abAc etc
    # \s+       space one or more
    # import    literal text
    # \s+       space one or more
    # \w+       word character (a-zA-z0-9_) one or more
    # |  OR 
    # import     literal text
    # \s+        space one or more
    # \w+        word character (a-zA-z0-9_) one or more
    module_lines_iter = re.finditer(r'from\s+[\w\.]+\s+import\s+\w+|import\s+\w+', text)
    # the reason I'm using finditer is because it returns full match instead of partial matches.
    
    for m in module_lines_iter:
        line = m.group()
        line = line.replace(r'from\s+','')
        
        line_parts = line.split(' ')
        module_part = line_parts[1] # 2. item => nltk.corpus 
        
        # in case it has submodules
        module_part = module_part.split('.')[0].strip() # even if it doesn't have any dots, it will return an array the first index is the module
        
        print (line,'-->', module_part)
        modules.append(module_part)
        
    return modules

# get_modules_from_notebook('../../Week1/load_xml.ipynb')
# get_modules_from_notebook('../../Week4/homework/AlternativeCsvPreparation.ipynb')

# %%
all_modules = []

for path, file in all_notebooks:
    modules = get_modules_from_notebook(path)
    all_modules.extend(modules)
# Out:
# import csv --> csv
# import pandas --> pandas
# import this --> this
# import random --> random
# import xmltodict --> xmltodict
# import json --> json
# from collections import OrderedDict --> collections
# from xml.dom import minidom --> xml
# import xml --> xml
# import json --> json
# import json --> json
# import csv --> csv
# import pandas --> pandas
# import this --> this
# import random --> random
# import xmltodict --> xmltodict
# import json --> json
# from collections import OrderedDict --> collections
# from xml.dom import minidom --> xml
# import xml --> xml
# import random --> random
# import matplotlib --> matplotlib
# import pandas --> pandas
# from datetime import datetime --> datetime
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import numpy --> numpy
# import pandas --> pandas
# from datetime import datetime --> datetime
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import numpy --> numpy
# import random --> random
# import matplotlib --> matplotlib
# import pandas --> pandas
# import pandas --> pandas
# import random --> random
# import seaborn --> seaborn
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# from datetime import datetime --> datetime
# import numpy --> numpy
# import pandas --> pandas
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import random --> random
# import timeit --> timeit
# import random --> random
# import matplotlib --> matplotlib
# import seaborn --> seaborn
# import pandas --> pandas
# import numpy --> numpy
# import random --> random
# import pandas --> pandas
# import matplotlib --> matplotlib
# import numpy --> numpy
# import numpy --> numpy
# import pandas --> pandas
# import random --> random
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# from pandas.plotting import register_matplotlib_converters --> pandas
# import random --> random
# import timeit --> timeit
# import time --> time
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import seaborn --> seaborn
# import random --> random
# import random --> random
# import matplotlib --> matplotlib
# import seaborn --> seaborn
# import pandas --> pandas
# import numpy --> numpy
# import numpy --> numpy
# import pandas --> pandas
# import random --> random
# import pandas --> pandas
# import pandas --> pandas
# import random --> random
# import seaborn --> seaborn
# import random --> random
# import timeit --> timeit
# import time --> time
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import seaborn --> seaborn
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import random --> random
# import matplotlib --> matplotlib
# import seaborn --> seaborn
# import pandas --> pandas
# import numpy --> numpy
# import seaborn --> seaborn
# import random --> random
# import timeit --> timeit
# import numpy --> numpy
# import pandas --> pandas
# import random --> random
# import pandas --> pandas
# import matplotlib --> matplotlib
# import numpy --> numpy
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# from datetime import datetime --> datetime
# import random --> random
# import random --> random
# import timeit --> timeit
# import doctest --> doctest
# import numpy --> numpy
# import random --> random
# import pandas --> pandas
# import matplotlib --> matplotlib
# import scipy --> scipy
# from scipy import signal --> scipy
# import pandas --> pandas
# import numpy --> numpy
# import matplotlib --> matplotlib
# import datetime --> datetime
# import pytz --> pytz
# import pandas --> pandas
# import pickle --> pickle
# import pytz --> pytz
# import matplotlib --> matplotlib
# import time --> time
# import datetime --> datetime
# import datetime --> datetime
# import pandas --> pandas
# import pytz --> pytz
# import pandas --> pandas
# import matplotlib --> matplotlib
# import numpy --> numpy
# import pandas --> pandas
# import numpy --> numpy
# import glob --> glob
# from scipy.fftpack import fft --> scipy
# from statsmodels.tsa.seasonal import seasonal_decompose --> statsmodels
# from statsmodels.graphics.tsaplots import plot_acf --> statsmodels
# import random --> random
# import time --> time
# import matplotlib --> matplotlib
# import pandas --> pandas
# import numpy --> numpy
# import glob --> glob
# from scipy.fftpack import fft --> scipy
# from statsmodels.tsa.seasonal import seasonal_decompose --> statsmodels
# from statsmodels.graphics.tsaplots import plot_acf --> statsmodels
# import random --> random
# import time --> time
# import matplotlib --> matplotlib
# from pandas.plotting import register_matplotlib_converters --> pandas
# import requests --> requests
# import re --> re
# from bs4 import BeautifulSoup --> bs4
# import pandas --> pandas
# import glob --> glob
# import zipfile --> zipfile
# from statsmodels.tsa.seasonal import seasonal_decompose --> statsmodels
# import random --> random
# import time --> time
# import matplotlib --> matplotlib
# import os --> os
# import pandas --> pandas
# import numpy --> numpy
# import glob --> glob
# from scipy.fftpack import fft --> scipy
# from statsmodels.tsa.seasonal import seasonal_decompose --> statsmodels
# from statsmodels.graphics.tsaplots import plot_acf --> statsmodels
# import random --> random
# import time --> time
# import matplotlib --> matplotlib
# import requests --> requests
# import re --> re
# from bs4 import BeautifulSoup --> bs4
# import pandas --> pandas
# import glob --> glob
# import zipfile --> zipfile
# from statsmodels.tsa.seasonal import seasonal_decompose --> statsmodels
# import random --> random
# import time --> time
# import matplotlib --> matplotlib
# import os --> os
# import pandas --> pandas
# import numpy --> numpy
# import glob --> glob
# from scipy.fftpack import fft --> scipy
# from statsmodels.tsa.seasonal import seasonal_decompose --> statsmodels
# from statsmodels.graphics.tsaplots import plot_acf --> statsmodels
# import random --> random
# import time --> time
# import matplotlib --> matplotlib
# import datetime --> datetime
# import pandas --> pandas
# import pytz --> pytz
# import pandas --> pandas
# import numpy --> numpy
# import matplotlib --> matplotlib
# import numpy --> numpy
# import random --> random
# import pandas --> pandas
# import matplotlib --> matplotlib
# import scipy --> scipy
# from scipy import signal --> scipy
# import pandas --> pandas
# import pickle --> pickle
# import pytz --> pytz
# import matplotlib --> matplotlib
# import time --> time
# import datetime --> datetime
# import datetime --> datetime
# import pytz --> pytz
# import pandas --> pandas
# import matplotlib --> matplotlib
# import numpy --> numpy
# import pandas --> pandas
# import numpy --> numpy
# import glob --> glob
# import matplotlib --> matplotlib
# import seaborn --> seaborn
# from scipy import stats --> scipy
# import pickle --> pickle
# import time --> time
# from pandas.plotting import register_matplotlib_converters --> pandas
# import requests --> requests
# import json --> json
# import subprocess --> subprocess
# import psutil --> psutil
# import pickle --> pickle
# import os --> os
# import time --> time
# import datetime --> datetime
# import pandas --> pandas
# import matplotlib --> matplotlib
# import pandas --> pandas
# import numpy --> numpy
# import glob --> glob
# import matplotlib --> matplotlib
# import seaborn --> seaborn
# from scipy import stats --> scipy
# import pickle --> pickle
# import time --> time
# import requests --> requests
# import json --> json
# import subprocess --> subprocess
# import psutil --> psutil
# import pickle --> pickle
# import os --> os
# import time --> time
# import datetime --> datetime
# import pandas --> pandas
# import matplotlib --> matplotlib
# from faker import Faker --> faker
# import random --> random
# import numpy --> numpy
# import pandas --> pandas
# from datetime import datetime --> datetime
# from faker import Faker --> faker
# import random --> random
# import numpy --> numpy
# import pandas --> pandas
# from datetime import datetime --> datetime
# import os --> os
# import sys --> sys
# import h5py --> h5py
# import pandas --> pandas
# import numpy --> numpy
# import sqlite3 --> sqlite3
# import pickle --> pickle
# from faker import Faker --> faker
# import time --> time
# import random --> random
# import string --> string
# import time --> time
# import matplotlib --> matplotlib
# import random --> random
# import string --> string
# import time --> time
# import matplotlib --> matplotlib
# import random --> random
# import matplotlib --> matplotlib
# import time --> time
# import python --> python
# import pandas --> pandas
# import numpy --> numpy
# import pickle --> pickle
# import matplotlib --> matplotlib
# import time --> time
# import os --> os
# import sys --> sys
# import h5py --> h5py
# import pandas --> pandas
# import numpy --> numpy
# import sqlite3 --> sqlite3
# import pickle --> pickle
# from faker import Faker --> faker
# import time --> time
# import python --> python
# import pandas --> pandas
# import numpy --> numpy
# import pickle --> pickle
# import matplotlib --> matplotlib
# import time --> time
# from pycallgraph import PyCallGraph --> pycallgraph
# from pycallgraph.output import GraphvizOutput --> pycallgraph
# from IPython.display import Image --> IPython
# import random --> random
# from IPython.display import Image --> IPython
# import random --> random
# import matplotlib --> matplotlib
# import time --> time
# import random --> random
# import string --> string
# import time --> time
# import matplotlib --> matplotlib
# import glob --> glob
# import os --> os
# from os import walk --> os
# from graphviz import Digraph --> graphviz
# from IPython.display import Image --> IPython
# from graphviz import Digraph --> graphviz
# from IPython.display import Image --> IPython
# import pydot --> pydot
# import random --> random
# import string --> string
# import time --> time
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# from networkx import nx --> networkx
# import warnings --> warnings
# import networkx --> networkx
# import numpy --> numpy
# import networkx --> networkx
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# from datetime import datetime --> datetime
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import timeit --> timeit
# import random --> random
# import datetime --> datetime
# import re --> re
# import random --> random
# import random --> random
# import datetime --> datetime
# import re --> re
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# from datetime import datetime --> datetime
# import random --> random
# import datetime --> datetime
# import re --> re
# import timeit --> timeit
# import random --> random
# import datetime --> datetime
# import re --> re
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import sys --> sys
# from jinja2 import Environment --> jinja2
# from jinja2 import Environment --> jinja2
# import sys --> sys
# from jinja2 import Environment --> jinja2
# from jinja2 import Environment --> jinja2
# from PyPDF2 import PdfFileMerger --> PyPDF2
# from PyPDF2 import PdfFileMerger --> PyPDF2
# from selenium import webdriver --> selenium
# from selenium import webdriver --> selenium
# import xhtml2pdf --> xhtml2pdf
# from IPython.display import display --> IPython
# from xhtml2pdf import pisa --> xhtml2pdf
# import python --> python
# import xhtml2pdf --> xhtml2pdf
# from IPython.display import display --> IPython
# from xhtml2pdf import pisa --> xhtml2pdf
# import python --> python
# import re --> re
# import pandas --> pandas
# from filename import DataCleaner --> filename
# import filename --> filename
# import random --> random
# from random import randint --> random
# from faker import Faker --> faker
# import faker --> faker
# import pandas --> pandas
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import browserhistory --> browserhistory
# import pandas --> pandas
# from urllib.parse import urlparse --> urllib
# import pandas --> pandas
# import random --> random
# from faker import Faker --> faker
# from faker import Faker --> faker
# from faker import Faker --> faker
# import pandas --> pandas
# from browser_history.browsers import Firefox --> browser_history
# import browserhistory --> browserhistory
# import pandas --> pandas
# from urllib.parse import urlparse --> urllib
# from browser_history.browsers import Firefox --> browser_history
# import pandas --> pandas
# import pandas --> pandas
# import random --> random
# from faker import Faker --> faker
# from faker import Faker --> faker
# from faker import Faker --> faker
# import pandas --> pandas
# import pandas --> pandas
# import matplotlib --> matplotlib
# import matplotlib --> matplotlib
# import time --> time
# import pandas --> pandas
# import matplotlib --> matplotlib
# import time --> time
# import pandas --> pandas
# import time --> time
# import pandas --> pandas
# import pandas --> pandas
# import or --> or
# import time --> time
# import pandas --> pandas
# import pandas --> pandas
# import missingno --> missingno
# import matplotlib --> matplotlib
# import time --> time
# import pandas --> pandas
# import time --> time
# import pandas --> pandas
# import pandas --> pandas
# import matplotlib --> matplotlib
# import time --> time
# import pandas --> pandas
# import time --> time
# import pandas --> pandas
# import time --> time
# import pandas --> pandas
# import time --> time
# import pandas --> pandas
# import matplotlib --> matplotlib
# import time --> time
# import pandas --> pandas
# import time --> time
# import pandas --> pandas
# import pandas --> pandas
# import missingno --> missingno
# import matplotlib --> matplotlib
# import pandas --> pandas
# import or --> or
# import pandas --> pandas
# import matplotlib --> matplotlib
# import re --> re
# import pandas --> pandas
# from filename import DataCleaner --> filename
# import filename --> filename
# import random --> random
# from random import randint --> random
# from faker import Faker --> faker
# import faker --> faker
# import pandas --> pandas
# import pandas --> pandas
# import pandas --> pandas
# import pandas --> pandas
# import numpy --> numpy
# import random --> random
# from faker import Faker --> faker
# import pandas --> pandas
# import pandas --> pandas
# import pandas --> pandas
# import numpy --> numpy
# import random --> random
# from faker import Faker --> faker
# import pandas --> pandas
# import requests --> requests
# from bs4 import BeautifulSoup --> bs4
# import pandas --> pandas
# from bs4 import BeautifulSoup --> bs4
# import requests --> requests
# from docx import Document --> docx
# import os --> os
# import requests --> requests
# import pandas --> pandas
# import PyPDF2 --> PyPDF2
# import re --> re
# import requests --> requests
# import re --> re
# import requests --> requests
# from bs4 import BeautifulSoup --> bs4
# from docx import Document --> docx
# import PyPDF2 --> PyPDF2
# import re --> re
# import requests --> requests
# import pandas --> pandas
# import requests --> requests
# from bs4 import BeautifulSoup --> bs4
# import pandas --> pandas
# import requests --> requests
# from bs4 import BeautifulSoup --> bs4
# import requests --> requests
# import re --> re
# from docx import Document --> docx
# import os --> os
# from bs4 import BeautifulSoup --> bs4
# import requests --> requests
# import docx --> docx
# import os --> os
# import zipfile --> zipfile
# import requests --> requests
# import docx --> docx
# from nltk.corpus import stopwords --> nltk
# from nltk.tokenize import word_tokenize --> nltk
# import string --> string
# from file_processor import FileProcessor --> file_processor
# from nltk.corpus import stopwords --> nltk
# from nltk.tokenize import word_tokenize --> nltk
# import docx --> docx
# import string --> string
# import re --> re
# from file_processor import FileProcessor --> file_processor
# from nltk.corpus import stopwords --> nltk
# from nltk.tokenize import word_tokenize --> nltk
# import docx --> docx
# import string --> string
# import re --> re
# from file_processor import FileProcessor --> file_processor
# from nltk.corpus import stopwords --> nltk
# from nltk.tokenize import word_tokenize --> nltk
# import docx --> docx
# import string --> string
# import re --> re
# import os --> os
# import zipfile --> zipfile
# import requests --> requests
# import docx --> docx
# from nltk.corpus import stopwords --> nltk
# from nltk.tokenize import word_tokenize --> nltk
# import re --> re
# import math --> math
# import os --> os
# import fnmatch --> fnmatch
# import pandas --> pandas
# from sklearn.feature_extraction.text import TfidfVectorizer --> sklearn
# from sklearn.feature_extraction import text --> sklearn
# from sklearn.metrics.pairwise import cosine_similarity --> sklearn
# import matplotlib --> matplotlib
# import numpy --> numpy
# from sklearn.datasets.samples_generator import make_blobs --> sklearn
# from sklearn.metrics import pairwise_distances_argmin --> sklearn
# import nltk --> nltk
# from nltk.tokenize import sent_tokenize --> nltk
# from nltk.corpus import stopwords --> nltk
# import pandas --> pandas
# import myfunctions --> myfunctions
# from myfunctions import unique_entries_in_frame --> myfunctions
# import random --> random
# import pandas --> pandas
# import pandas --> pandas
# import numpy --> numpy
# import os --> os
# import matplotlib --> matplotlib
# import numpy --> numpy
# from sklearn.datasets.samples_generator import make_blobs --> sklearn
# from sklearn.metrics import pairwise_distances_argmin --> sklearn
# import matplotlib --> matplotlib
# import numpy --> numpy
# from sklearn.datasets.samples_generator import make_blobs --> sklearn
# from sklearn.metrics import pairwise_distances_argmin --> sklearn
# import random --> random
# import pandas --> pandas
# import math --> math
# import os --> os
# import fnmatch --> fnmatch
# import pandas --> pandas
# import myfunctions --> myfunctions
# from myfunctions import unique_entries_in_frame --> myfunctions
# import nltk --> nltk
# from nltk.tokenize import sent_tokenize --> nltk
# from nltk.corpus import stopwords --> nltk
# import matplotlib --> matplotlib
# import numpy --> numpy
# from sklearn.datasets.samples_generator import make_blobs --> sklearn
# from sklearn.metrics import pairwise_distances_argmin --> sklearn
# import math --> math
# import os --> os
# import fnmatch --> fnmatch
# import pandas --> pandas
# from sklearn.feature_extraction.text import TfidfVectorizer --> sklearn
# from sklearn.feature_extraction import text --> sklearn
# from sklearn.metrics.pairwise import cosine_similarity --> sklearn
# import re --> re
# import pandas --> pandas
# import numpy --> numpy
# import os --> os
# import matplotlib --> matplotlib
# from networkx import nx --> networkx
# import warnings --> warnings
# import networkx --> networkx
# import numpy --> numpy
# from graphviz import Digraph --> graphviz
# from IPython.display import Image --> IPython
# import pydot --> pydot
# import networkx --> networkx
# import glob --> glob
# import os --> os
# from os import walk --> os
# from graphviz import Digraph --> graphviz
# from IPython.display import Image --> IPython
# from pycallgraph import PyCallGraph --> pycallgraph
# from pycallgraph.output import GraphvizOutput --> pycallgraph
# from IPython.display import Image --> IPython
# import random --> random
# from IPython.display import Image --> IPython
# from pycallgraph import PyCallGraph --> pycallgraph
# from pycallgraph.output import GraphvizOutput --> pycallgraph
# from IPython.display import Image --> IPython
# import random --> random
# from IPython.display import Image --> IPython
# import glob --> glob
# import os --> os
# from os import walk --> os
# from graphviz import Digraph --> graphviz
# from IPython.display import Image --> IPython
# from graphviz import Digraph --> graphviz
# from IPython.display import Image --> IPython
# import pydot --> pydot
# import matplotlib --> matplotlib
# from networkx import nx --> networkx
# import warnings --> warnings
# import networkx --> networkx
# import numpy --> numpy
# import networkx --> networkx

# %%
set(all_modules )
# Out:
# {'IPython',
#  'PyPDF2',
#  'browser_history',
#  'browserhistory',
#  'bs4',
#  'collections',
#  'csv',
#  'datetime',
#  'doctest',
#  'docx',
#  'faker',
#  'file_processor',
#  'filename',
#  'fnmatch',
#  'glob',
#  'graphviz',
#  'h5py',
#  'jinja2',
#  'json',
#  'math',
#  'matplotlib',
#  'missingno',
#  'myfunctions',
#  'networkx',
#  'nltk',
#  'numpy',
#  'or',
#  'os',
#  'pandas',
#  'pickle',
#  'psutil',
#  'pycallgraph',
#  'pydot',
#  'python',
#  'pytz',
#  'random',
#  're',
#  'requests',
#  'scipy',
#  'seaborn',
#  'selenium',
#  'sklearn',
#  'sqlite3',
#  'statsmodels',
#  'string',
#  'subprocess',
#  'sys',
#  'this',
#  'time',
#  'timeit',
#  'urllib',
#  'warnings',
#  'xhtml2pdf',
#  'xml',
#  'xmltodict',
#  'zipfile'}
