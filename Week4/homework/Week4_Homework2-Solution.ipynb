# %% [markdown]
# Write a class that generates fake data.
#
# * Write the code under the py docs ( do NOT remove py docs )
# * Before comitting do a Restart & Run All

# %%
import pandas as pd
import random
from faker import Faker

class FakeDataGenerator:
    
    def __init__(self, df = None, rows=5):
        """
        This class generates fake data
        
        If data frame is passed in it will add the fake data to it. 
        Otherwise, it will create a new data frame
        
        Parameters:
        -----------
        df: 
          DataFrame default is None
          
        rows:
          If df None, this parameter will be used to create a data frame with `row` length
        """
        # code goes under this line. 
        # I will deduct points if any code is written above the comments!
          
        self.fake = Faker()
        
        if df is not None:
            self.df = df
            self.rows = len(df)
        else:
            self.df = pd.DataFrame()
            self.rows = rows
        
        
    def add_random_number(self, column_name, small_value, high_value): # optional: add probabilities 
        """
        adds fake numbers to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [random.randint(small_value,high_value) for i in range(self.rows)]
        
        return self.df       
    
        
    def add_name(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.first_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_last_name(self, column_name):
        """
        adds fake last name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.last_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_email(self, column_name):
        """
        adds fake email to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.email() for i in range(self.rows)]
        
        return self.df
    
    
    def add_phone_number(self, column_name):
        """
        adds fake phone number to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        from faker import Faker
        fake = Faker()
        
        self.df[column_name] = [self.fake.phone_number() for i in range(self.rows)]
        
        return self.df
    
    
    def add_address(self, column_name):
        """
        adds fake address to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        from faker import Faker
        fake = Faker()
        
        self.df[column_name] = [self.fake.address() for i in range(self.rows)]
        
        return self.df

# %%
import pandas as pd

# Case 1 - existing data frame 
df = pd.DataFrame()
df['product_id'] = [i + 123 for i in range(25)]
df.head()
# Out:
#    product_id
# 0         123
# 1         124
# 2         125
# 3         126
# 4         127

# %%
fakeGen = FakeDataGenerator(df) # I'm creating instance using existing df
fakeGen.add_name('name')
fakeGen.add_last_name('lastname')
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
# Out:
#     product_id       name  lastname  \
# 0          123       Chad    Pierce
# 1          124       Kyle    Taylor
# 2          125      David    Vaughn
# 3          126    Natalie       Lee
# 4          127     Andrew     Mason
# 5          128  Katherine     Payne
# 6          129      Jacob     Bruce
# 7          130    Kenneth   Roberts
# 8          131     Ashley      Rice
# 9          132     George      Wolf
# 10         133    Barbara    Oneill
# 11         134     Steven  Peterson
# 12         135     Thomas      Mack
# 13         136    Tiffany    Miller
# 14         137    Dorothy    Hayden
# 15         138     Joseph  Robinson
# 16         139    Barbara    Rhodes
# 17         140    Charles  Harrison
# 18         141    Douglas      Todd
# 19         142  Elizabeth    Turner
# 20         143       Adam  Robinson
# 21         144     Shelly  Whitaker
# 22         145       Toni     Frank
# 23         146     Robert     Jones
# 24         147     Angela   Everett
#
#                                      shipping_address  \
# 0   8505 Pacheco Streets Suite 204\nJohnsontown, A...
# 1            3514 Ross Ports\nEvelynchester, WV 18669
# 2    415 Tristan Oval Suite 226\nHannahfurt, GA 84130
# 3   6294 Romero Walk Suite 865\nEast Lindastad, WY...
# 4   31107 Rose Plain Suite 731\nNew Jamesberg, ND ...
# 5               10603 Smith Ways\nJasonberg, NC 82150
# 6            714 Jennifer River\nDanielview, MO 30203
# 7   86974 Brown Stravenue Suite 547\nLake Stephani...
# 8    7332 Lewis Locks Apt. 267\nCharlesbury, NE 23023
# 9       53173 Emily Canyon\nEast Alicialand, PA 92096
# 10  15268 Taylor Rest Suite 667\nWest Kellyshire, ...
# 11      606 Jay Road Apt. 842\nHarrisonbury, NY 44883
# 12  372 Cynthia Rue Suite 185\nNorth Douglas, NV 2...
# 13   718 Taylor Circles Apt. 519\nZhangfort, CO 66948
# 14         0180 Yu Ridges\nPort Williamstad, MT 95622
# 15  11942 Hannah Vista Apt. 286\nNorth Cynthia, VA...
# 16  7410 Kenneth Place Apt. 186\nAlexandraport, WV...
# 17   959 Scott Cliff Apt. 882\nWest Jeffrey, GA 51789
# 18  53613 Dixon Crossroad Suite 868\nNorth Michell...
# 19     703 Sara Track Apt. 375\nWest Dennis, TN 91022
# 20           1195 Pugh Trace\nEast Brittany, SC 72928
# 21  5261 Barbara Meadow Apt. 189\nFraziertown, RI ...
# 22                   PSC 5771, Box 4180\nAPO AP 97754
# 23         38382 Tina Mountain\nBarnettfurt, AR 05868
# 24  2485 Michael Road Suite 467\nNew Thomashaven, ...
#
#                                       billing_address         customer_phone
# 0     06400 Irwin Pines\nNorth Jenniferland, MT 11992   001-587-350-9204x065
# 1          67216 Keller Freeway\nGrossshire, SD 35848    (210)285-1652x35924
# 2   8846 Johnson Dale Suite 625\nNew Michaelland, ...    +1-761-879-9237x364
# 3     44965 Kyle Vista Apt. 217\nNew Teresa, MS 31404      (000)023-9407x722
# 4     966 Park Common Suite 231\nEast Stacy, GA 32074  001-655-306-4936x7514
# 5                    Unit 5039 Box 3761\nDPO AA 81489       001-872-005-4243
# 6          53771 Torres Pass\nEast Troyfort, MO 55880           323.984.7736
# 7      0625 John Shore Apt. 076\nWest Henry, PA 32365  +1-435-459-3634x61021
# 8   3120 Edward Trail Suite 206\nLake Brentburgh, ...       456.327.9865x602
# 9         3658 Burch Shore\nChristopherfort, KS 47192           487.070.9638
# 10   9846 Wendy Unions Apt. 648\nDarrenbury, TN 04447             7125677382
# 11  7195 Pennington Stravenue Apt. 194\nPort Alyss...           309.941.5062
# 12  4231 Chang Turnpike Suite 320\nNew Charles, NM...   +1-006-414-2580x1463
# 13         5735 Steven Road\nNorth Josestad, OH 05477        +1-743-317-8294
# 14  7348 Shaw Corners Apt. 878\nNew Williamview, U...  001-427-957-1720x9018
# 15  05131 Jeremy Unions Suite 059\nMelissastad, WV...     927-628-4593x83529
# 16           08534 Nancy Village\nHillhaven, NV 72417       813-973-7075x078
# 17  81047 Smith Burgs Suite 803\nLake Julian, GA 5...       001-361-009-4271
# 18      371 Candice Lakes\nWest Matthewport, DE 83961           453.835.0853
# 19           21864 Scott Lodge\nPort Carrie, ND 80055     396-293-9610x10368
# 20  632 Stevens Divide Apt. 761\nWaltonhaven, WA 3...           863-694-8361
# 21              136 Karen Point\nHobbsmouth, RI 44880   +1-075-254-0661x0460
# 22               10357 Amber Via\nSamuelton, MD 61982          (240)799-0612
# 23  471 Derek Spur Apt. 369\nEast Omarshire, HI 03091      485-280-6854x7573
# 24  53772 Ashlee Park Apt. 314\nNorth Ashleybury, ...      (031)106-3127x906

# %%
# Case 2 - no dataframe

fakeGen = FakeDataGenerator() # no df
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
fakeGen.add_random_number('sale_count', 10, 100)
# Out:
#                                     shipping_address  \
# 0  1543 Jerry Greens Apt. 012\nChristensenport, I...
# 1                   PSC 6320, Box 3264\nAPO AP 82614
# 2              146 Anna Ferry\nNorth Emily, WV 16288
# 3  19402 Michael Ridge Suite 252\nEast Anna, PA 9...
# 4  4307 Sean Mill Suite 202\nNorth Ericaview, WI ...
#
#                                      billing_address          customer_phone  \
# 0           138 Davidson Fork\nCookborough, NC 20471   001-326-189-3490x5054
# 1   16585 Clark Center Apt. 268\nColinside, NE 71613       252.942.0832x3202
# 2  5315 Fisher Points Apt. 510\nNew Cynthia, OK 4...  001-386-919-3352x94396
# 3  42529 Brown Rapids Suite 855\nJoanborough, WI ...  001-113-781-6551x47030
# 4      3909 Julia Crescent\nAlexandershire, NM 48838        001-342-316-7535
#
#    sale_count
# 0          31
# 1          77
# 2          52
# 3          59
# 4          84
