# %% [markdown]
# Write a class that generates fake data.
#
# * Write the code under the py docs ( do NOT remove py docs )
# * Before comitting do a Restart & Run All

# %%
import pandas as pd
import random
from faker import Faker

class FakeDataGenerator:
    
    def __init__(self, df = None, rows=5):
        """
        This class generates fake data
        
        If data frame is passed in it will add the fake data to it. 
        Otherwise, it will create a new data frame
        
        Parameters:
        -----------
        df: 
          DataFrame default is None
          
        rows:
          If df None, this parameter will be used to create a data frame with `row` length
        """
        # code goes under this line. 
        # I will deduct points if any code is written above the comments!
          
        self.fake = Faker()
        
        if df is not None:
            self.df = df
            self.rows = self.df.shape[0] 
        else:
            self.df = pd.DataFrame()
            self.rows = rows
        
        
    def add_random_number(self, column_name, small_value, high_value): # optional: add probabilities 
        """
        adds fake numbers to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [random.randint(small_value,high_value) for i in range(self.rows)]
        
        return self.df       
    
        
    def add_name(self, column_name):
        """
        adds fake name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.first_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_last_name(self, column_name):
        """
        adds fake last name to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        
        self.df[column_name] = [self.fake.last_name() for i in range(self.rows)]
        
        return self.df
    
    
    def add_email(self, column_name):
        """
        adds fake email to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """

        self.df[column_name] = [self.fake.email() for i in range(self.rows)]
        
        return self.df
    
    
    def add_phone_number(self, column_name):
        """
        adds fake phone number to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        from faker import Faker
        fake = Faker()
        
        self.df[column_name] = [self.fake.phone_number() for i in range(self.rows)]
        
        return self.df
    
    
    def add_address(self, column_name):
        """
        adds fake address to the data frame with `column_name`
        
        Returns
        -------
        data frame
        """
        from faker import Faker
        fake = Faker()
        
        self.df[column_name] = [self.fake.address() for i in range(self.rows)]
        
        return self.df

# %%
import pandas as pd

# Case 1 - existing data frame 
df = pd.DataFrame()
df['product_id'] = [i + 123 for i in range(25)]
df.head()
# Out:
#    product_id
# 0         123
# 1         124
# 2         125
# 3         126
# 4         127

# %%
fakeGen = FakeDataGenerator(df) # I'm creating instance using existing df
fakeGen.add_name('name')
fakeGen.add_last_name('lastname')
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
# Out:
#     product_id       name  lastname  \
# 0          123     Nicole   Flowers
# 1          124       Anne   Kennedy
# 2          125  Elizabeth      Diaz
# 3          126     Cheryl       Day
# 4          127      Kayla     Combs
# 5          128     Sherri     Vance
# 6          129     Shelby   Simmons
# 7          130      David    Brewer
# 8          131      Glenn     Cohen
# 9          132     Taylor    Murphy
# 10         133  Mackenzie   Brennan
# 11         134       John    Hughes
# 12         135       Jeff     Young
# 13         136      Sarah    Cooper
# 14         137      Kevin    Murphy
# 15         138     Daniel    Baxter
# 16         139       John  Arellano
# 17         140   Jennifer     Lyons
# 18         141      Jorge    Garcia
# 19         142       John     Blair
# 20         143      Donna    Carter
# 21         144    Michele     Reese
# 22         145       Tony    Gordon
# 23         146  Elizabeth     Brown
# 24         147      Linda     Smith
#
#                                      shipping_address  \
# 0           092 Mccarthy Skyway\nRileyville, SD 21111
# 1                            USS Santos\nFPO AP 22086
# 2   05900 Marcus Road Apt. 990\nLake Maryburgh, KS...
# 3                       USS Fitzpatrick\nFPO AP 02754
# 4            0015 James Manors\nWrighthaven, MO 93196
# 5            4796 Jessica Hill\nShannontown, UT 02641
# 6   0660 Johnny Cliff Apt. 044\nUnderwoodborough, ...
# 7               9953 Nicole Via\nMaciasbury, AR 09528
# 8   236 Kenneth Divide Apt. 765\nJuarezview, OH 04740
# 9      69430 Gregory Meadow\nLake Craigside, VA 54855
# 10    2752 Dean Flats Apt. 930\nJeremiahton, NV 44305
# 11  36540 Mcknight Light\nNorth Carolynview, NM 98612
# 12         508 Jeffrey Islands\nPort Steven, MD 58285
# 13  5104 Stephanie Village Apt. 990\nJonesview, SD...
# 14                           USS Bright\nFPO AA 94489
# 15  5069 Moore Expressway Apt. 051\nEast Ronald, O...
# 16           15221 Casey Canyon\nPiercebury, TX 99735
# 17                          USCGC Sloan\nFPO AA 75940
# 18  3380 Eric Forks Apt. 577\nPort Debbieport, NC ...
# 19  1009 Joseph Rapids Apt. 210\nBlackwellport, TX...
# 20   505 Jimmy Trail Apt. 540\nJamesborough, FL 82462
# 21  781 Martinez Hollow Apt. 493\nPort Amanda, TX ...
# 22          665 Juarez Shores\nStoneborough, MD 09694
# 23   6056 Morgan Route Apt. 966\nBrownshire, WA 24765
# 24  801 Peterson Shore Suite 866\nCardenasland, OR...
#
#                                       billing_address        customer_phone
# 0        352 Holt Row Suite 928\nMillertown, AL 26500          923-648-2214
# 1      615 Angela Radial Apt. 519\nBradport, VT 09506  001-011-981-7763x062
# 2      17064 Flynn Road Apt. 609\nJasonberg, MT 67566   +1-931-904-0934x790
# 3   424 Hardin Cove Suite 872\nBruceborough, DC 70169          684.770.0406
# 4          822 Heather Village\nEast Robert, TX 99924      001-043-224-1140
# 5   10641 Humphrey Divide Apt. 178\nYoungbury, CT ...  +1-066-409-9060x1180
# 6    55066 Singh Bypass\nNorth Gregoryburgh, WA 55702          178-371-9682
# 7          8635 Vaughn Passage\nPort Amanda, KY 23446    (367)924-2907x7093
# 8                901 Ryan Rue\nMalloryhaven, OR 30703          863.263.4166
# 9   16053 Nicholas Rue Suite 521\nNew Scott, NC 76392   +1-897-875-0827x147
# 10            47571 Quinn Rest\nWest Kendra, RI 52523   (958)554-2610x86530
# 11  443 Sheryl Loop Suite 155\nLake Jennashire, HI...      666.882.9772x960
# 12            282 Mullins Manor\nSelenaberg, KY 94372      467.193.4071x683
# 13  47621 Saunders Freeway Apt. 460\nNorth Lisasta...   +1-842-060-2249x990
# 14          1511 Owens Corners\nLake Carrie, WA 46489            8012358171
# 15     741 Cohen Ville Apt. 106\nDanielside, TX 95073    059-192-1981x36893
# 16                   PSC 3904, Box 5194\nAPO AE 50952      001-178-969-2301
# 17  43009 Zhang Court Suite 962\nJacksonhaven, AZ ...    (193)686-5195x9545
# 18  9844 Kathleen Trail Suite 140\nPort Annettevil...          838.395.0589
# 19  80080 Anderson Viaduct Apt. 179\nRyanview, NM ...    (944)685-3755x5734
# 20          484 Nguyen Fields\nRobinborough, IA 87868          121-757-3768
# 21          1122 Hayes Glens\nDanielborough, MN 51680     942.963.9214x7910
# 22       2748 Jones Corner\nWilliamsborough, CO 97676      378.618.4029x911
# 23               7903 Gill Pass\nGrahamtown, KS 90879   +1-863-703-4272x079
# 24  9866 Steven Curve Apt. 567\nEast Sabrina, MT 5...     654.608.2000x7426

# %%
# Case 2 - no dataframe

fakeGen = FakeDataGenerator() # no df
fakeGen.add_address('shipping_address')
fakeGen.add_address('billing_address')
fakeGen.add_phone_number('customer_phone')
fakeGen.add_random_number('sale_count', 10, 100)
# Out:
#                                     shipping_address  \
# 0  28104 Laura Freeway Apt. 251\nPort Samueltown,...
# 1       2421 Robin Flats\nWest Valerietown, VT 29943
# 2            35739 Green Lakes\nPruittview, MI 21972
# 3         243 Holloway Corner\nMelissafurt, NV 56481
# 4  363 Rodriguez Port Suite 935\nFrancisbury, WY ...
#
#                                      billing_address         customer_phone  \
# 0         806 James Islands\nEast Rosetown, MI 51269  +1-311-425-1662x36973
# 1            683 John Square\nMadisonville, AZ 98304           884-632-3967
# 2  150 Michelle Lodge Suite 926\nAdamsfort, NE 36769  +1-979-101-7601x56269
# 3  141 Joshua Springs Apt. 878\nLake Daniel, IN 2...  001-556-225-8984x5697
# 4          47274 Giles Glen\nWest Josefort, VT 74768           031-632-2243
#
#    sale_count
# 0          92
# 1          16
# 2          29
# 3          99
# 4          56
