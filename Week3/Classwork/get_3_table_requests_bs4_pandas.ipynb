# %%
import requests
import pandas
pandas.__version__
# Out:
# '0.25.1'

# %% [markdown]
# Let's try to get the list of states shown on this page: https://www.omnisci.com/docs/latest/3_apdx_states.html

# %% [markdown]
# Pandas passes the URL to urllib
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.read_html.html

# %%
page_content = pandas.read_html("https://docs.omnisci.com/v4.4.1/3_apdx_states.html")
page_content
# Out:
# [    0   1
#  0 NaN NaN,                    State Abbreviation
#  0                Alabama           AL
#  1                 Alaska           AK
#  2                Arizona           AZ
#  3               Arkansas           AR
#  4             California           CA
#  5               Colorado           CO
#  6            Connecticut           CT
#  7               Delaware           DE
#  8   District of Columbia           DC
#  9                Florida           FL
#  10               Georgia           GA
#  11                Hawaii           HI
#  12                 Idaho           ID
#  13              Illinois           IL
#  14               Indiana           IN
#  15                  Iowa           IA
#  16                Kansas           KS
#  17              Kentucky           KY
#  18             Louisiana           LA
#  19                 Maine           ME
#  20              Maryland           MD
#  21         Massachusetts           MA
# ...

# %%
type(page_content)
# Out:
# list

# %%
page_content[0]
# Out:
#     0   1
# 0 NaN NaN

# %%
page_content[1]
# Out:
#                    State Abbreviation
# 0                Alabama           AL
# 1                 Alaska           AK
# 2                Arizona           AZ
# 3               Arkansas           AR
# 4             California           CA
# 5               Colorado           CO
# 6            Connecticut           CT
# 7               Delaware           DE
# 8   District of Columbia           DC
# 9                Florida           FL
# 10               Georgia           GA
# 11                Hawaii           HI
# 12                 Idaho           ID
# 13              Illinois           IL
# 14               Indiana           IN
# 15                  Iowa           IA
# 16                Kansas           KS
# 17              Kentucky           KY
# 18             Louisiana           LA
# 19                 Maine           ME
# 20              Maryland           MD
# 21         Massachusetts           MA
# 22              Michigan           MI
# 23             Minnesota           MN
# ...

# %%
type(page_content[1])
# Out:
# pandas.core.frame.DataFrame
